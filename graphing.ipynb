# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Out:
# /var/folders/08/mmfj4s5j5pg965d_g3yc5b980000gn/T/ipykernel_86798/364958460.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
from datasets.get_dataset import get_dataset
from genetic.algorithm import genetic_algorithm

# %%
# for mutation_probability, crossover_probability in [(0.1, 0.1), (0.4, 0.1), (0.1, 0.4), (0.6, 0.6)]:

#     configuration = {
#         "epochs": 30,
#         "population_size": 10,
#         "steps": 2,
#         "mutation_prob": mutation_probability,
#         "crossover_prob": crossover_probability,
#         "force_cycle_length": None,
#     }

#     dataset = get_dataset("electricity", size=1000)

#     best_chromosome, num_pipelines_over_epochs, mean_per_epoch, best_per_epoch = genetic_algorithm(
#         configuration, dataset
#     )
#     plt.plot(range(30), num_pipelines_over_epochs, label=f"p(m): {mutation_probability}, p(c): {crossover_probability}")
# plt.xlabel('epoch')
# plt.ylabel('number of pipelines explored')
# plt.legend()
# plt.show()

# %%
# for i in range(5):
    
#     configuration = {
#         "epochs": 20,
#         "population_size": 10,
#         "steps": 2,
#         "mutation_prob": 0.2,
#         "crossover_prob": 0.2,
#         "force_cycle_length": None,
#     }

#     dataset = get_dataset("electricity", size=1000)

#     best_chromosome, num_pipelines_over_epochs, mean_per_epoch, best_per_epoch = genetic_algorithm(
#         configuration, dataset
#     )
#     plt.plot(range(20), mean_per_epoch, label=i)
# plt.xlabel('epoch')
# plt.ylabel('mean RMSE')
# plt.legend()
# plt.show()

# %%
# for i in range(5):
    
#     configuration = {
#         "epochs": 20,
#         "population_size": 10,
#         "steps": 2,
#         "mutation_prob": 0.4,
#         "crossover_prob": 0.4,
#         "force_cycle_length": 24,
#     }

#     dataset = get_dataset("electricity", size=1000)

#     best_chromosome, num_pipelines_over_epochs, mean_per_epoch, best_per_epoch = genetic_algorithm(
#         configuration, dataset
#     )
#     plt.plot(range(20), best_per_epoch, label=i)
# plt.xlabel('epoch')
# plt.ylabel('best RMSE')
# plt.legend()
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating 10 lists of 15 steps each with random data for demonstration
np.random.seed(0)  # For reproducible results
# data = np.random.rand(10, 15)

array1 = np.array([4.470328544005147, 3.483247803042744, 2.460349587454958, 2.515414422812449, 2.5165127921020707, 3.1721566069201153, 4.468834078236567, 3.5236690963799076, 3.305638272335557, 2.2816360026272973, 2.2126827225257157, 1.2097908457049218, 1.2262870515201487, 1.1929307469006882, 1.30013801917798, 1.256674710811973, 1.2647121251669802, 1.2624540028692566, 1.5810597561545594, 1.6107954974923402])
array2 = np.array([6.108241117276213, 5.741055401532664, 4.447954297917024, 4.527347222050329, 3.159223702390613, 2.16422046321245, 3.1397074102295384, 3.0931793732591, 3.0917433958663416, 3.088217434425053, 4.074060318934085, 4.1201985916090305, 3.1421463893730475, 2.1725365019803577, 2.172509826501162, 2.172509826501162, 2.264473486745783, 3.9407376330646597, 3.548844115072741, 4.152271028344353])
array3 = np.array([3.8467750810927877, 2.2820839349300366, 1.4160403266481818, 3.1538178723850265, 3.1800684768973193, 2.1877241980427664, 1.1983314966270897, 0.2068343438804352, 0.19886906399355014, 0.19934136007519646, 1.0947423009325, 1.0969090127918335, 1.0925397848205525, 0.48439493831069014, 0.44597944320617894, 0.5276210539289765, 0.5298614494936101, 0.4511861908751472, 0.542316329210844, 0.4583791459145565])
array4 = np.array([7.359961013959348, 5.386720415644733, 4.392804977409379, 3.3938798988796974, 2.204204164118023, 2.205417423347998, 1.3126947607213983, 0.2588090334769236, 0.165652287974258, 0.1008576382720849, 0.10775836402632208, 0.1124707681234689, 1.0866660479209496, 1.0936956887145481, 0.09361802802320618, 0.09765461804671463, 0.09225069124013635, 0.09208530567132385, 0.10628623330634619, 1.0839713222723637])

data = np.vstack([array1, array2, array3, array4])

# Calculating mean and standard deviation for average RMSE
means = np.mean(data, axis=0)
std_devs = np.std(data, axis=0)

# Calculating upper and lower bounds for the standard deviation
upper_bound = means + std_devs
lower_bound = means - std_devs

# Calculating the best (minimum) RMSE for each step
array1 = np.array([0.13082887757838277, 0.12919259037595973, 0.12919259037595973, 0.12919259037595973, 0.12919259037595973, 0.12919259037595973, 0.12919259037595973, 0.12919259037595973, 0.12919259037595973, 0.12919259037595973, 0.12919259037595973, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706])
array2 = np.array([0.17663790451348368, 0.17663790451348368, 0.14157115490968372, 0.14157115490968372, 0.14002244583802392, 0.1232853749251821, 0.1173627935328135, 0.1173627935328135, 0.1173627935328135, 0.1173627935328135, 0.1173627935328135, 0.1173627935328135, 0.1173627935328135, 0.08148657237982614, 0.08148657237982614, 0.08148657237982614, 0.08148657237982614, 0.08148657237982614, 0.08148657237982614, 0.08148657237982614])
array3 = np.array([0.13200277694400295, 0.13200277694400295, 0.13200277694400295, 0.12553932060082604, 0.12553932060082604, 0.10162729176037717, 0.10162729176037717, 0.10162729176037717, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.07075488592207706, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375])
array4 = np.array([0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375, 0.06956760973790375])

data_best = np.vstack([array1, array2, array3, array4])

best_rmse = np.mean(data_best, axis=0)
std_devs_best = np.std(data_best, axis=0)

# Calculating upper and lower bounds for the standard deviation
upper_bound_best = best_rmse + std_devs_best
lower_bound_best = best_rmse - std_devs_best

# X-axis values
x_values = range(1, len(means) + 1)

# Creating a figure and a set of subplots
fig, ax1 = plt.subplots()

# Plotting average RMSE with standard deviation on the left Y-axis
ax1.plot(
    x_values, means, "", label="Average Mean Absolute Percentage Error", color="blue"
)
ax1.fill_between(x_values, lower_bound, upper_bound, color="gray", alpha=0.2)
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Average Mean Absolute Percentage Error", color="blue")
ax1.tick_params("y", colors="blue")

# Creating a second Y-axis for best RMSE
ax2 = ax1.twinx()
ax2.plot(
    x_values, best_rmse, "", label="Best Mean Absolute Percentage Error", color="green"
)
ax2.fill_between(x_values, lower_bound_best, upper_bound_best, color="lightblue", alpha=0.3)
ax2.set_ylabel("Best Mean Absolute Percentage Error", color="green")
ax2.tick_params("y", colors="green")

# Adding title and legend
# |fig.tight_layout()

# Show plot
plt.show()

# %%
epochs = 20
x = np.arange(epochs)

# Sample data for the lines
data1_left = [
    4.470328544005147,
    3.483247803042744,
    2.460349587454958,

    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
    0.4780942261734121,
]
data4_right = [
    0.14592544047644837,
    0.14592544047644837,
    0.14592544047644837,
    0.14592544047644837,
    0.14592544047644837,
    0.14592544047644837,
    0.14592544047644837,
    0.13718515702511558,
    0.13718515702511558,
    0.13718515702511558,
    0.13718515702511558,
    0.13718515702511558,
    0.13718515702511558,
    0.13718515702511558,
    0.12523265726887697,
    0.12523265726887697,
    0.12523265726887697,
    0.12523265726887697,
    0.12523265726887697,
    0.12523265726887697,
]

# Points to be plotted at the last x-value of each line
point1_right = (x[-1], 0.1134)
point2_right = (x[-1], 0.1462)
point3_right = (x[-1], 0.1288)
point4_right = (x[-1], 0.1872)

# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Left axis lines and points
ax1.plot(x, data1_left, label="ElectricityH1: Avg.", color="blue")
ax1.plot(x, data2_left, label="ElectricityM1: Avg.", color="green")
ax1.plot(x, data3_left, label="Power Houston: Avg.", color="red")
ax1.plot(x, data4_left, label="Temp Houston: Avg.", color="orange")

# Right axis setup
ax2 = ax1.twinx()

# Right axis lines and points
ax2.plot(x, data1_right, label="ElectricityH1: Best", color="blue", linestyle="--")
ax2.plot(x, data2_right, label="ElectricityM1: Best", color="green", linestyle="--")
ax2.plot(x, data3_right, label="Power Houston: Best", color="red", linestyle="--")
ax2.plot(x, data4_right, label="Temp Houston: Best", color="orange", linestyle="--")
ax2.scatter(
    *point1_right,
    color="blue",
    s=100,
    edgecolor="black",
    zorder=5,
    label="ElectricityH1: TPOT"
)
ax2.scatter(
    *point2_right,
    color="green",
    s=100,
    edgecolor="black",
    zorder=5,
    label="ElectricityM1: TPOT"
)
ax2.scatter(
    *point3_right,
    color="red",
    s=100,
    edgecolor="black",
    zorder=5,
    label="Power Houston: TPOT"
)
ax2.scatter(
    *point4_right,
    color="orange",
    s=100,
    edgecolor="black",
    zorder=5,
    label="Temp Houston: TPOT"
)

# Labels, titles and legends
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Avg. Mean Absolute Percentage Error", color="black", loc='bottom')
ax2.set_ylabel("Best Mean Absolute Percentage Error", color="black")
# plt.title("Scores over time vs TPOT")
fig.legend(loc="upper left", frameon=True, facecolor="lightgray")

# Show plot
plt.show()

# %%
list1 = np.array([10, 14, 16, 20, 23, 28, 34, 36, 37, 39, 41, 46, 50, 52, 53, 56, 63, 68, 71, 76])
list2 = np.array([10, 15, 18, 21, 24, 25, 28, 31, 34, 38, 41, 43, 46, 49, 50, 52, 55, 57, 59, 61])
list3 = np.array([9, 11, 13, 18, 21, 24, 26, 28, 31, 33, 33, 35, 35, 35, 36, 38, 40, 42, 43, 43])
list4 = np.array([10, 13, 15, 17, 23, 30, 35, 36, 37, 40, 43, 46, 49, 51, 53, 56, 57, 61, 62, 64])

# Combine lists into a 2D array
data = np.array([list1, list2, list3, list4])

# Calculate the mean and standard deviation
mean = np.mean(data, axis=0)
std_dev = np.std(data, axis=0)

# Create an x-axis for plotting
x = np.arange(len(mean))

# Plotting
plt.plot(x, mean, label='Mean')
plt.fill_between(x, mean - std_dev, mean + std_dev, color='gray', alpha=0.5, label='Standard Deviation')

plt.xlabel('Epochs')
plt.ylabel('Number of explored pipelines')
# plt.title('Number of explored pipelines over 4 runs of 20 epochs')
# plt.legend()

plt.show()
